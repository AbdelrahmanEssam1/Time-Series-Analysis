# %% [markdown]
# # Time-Series-Analysis

# %% [markdown]
# ## Importing packages and data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('multiTimeline.csv',skiprows=1)
df.head()
# Out:
#      Month  diet: (Worldwide)  gym: (Worldwide)  finance: (Worldwide)
# 0  2004-01                100                28                    47
# 1  2004-02                 73                24                    47
# 2  2004-03                 66                23                    45
# 3  2004-04                 69                21                    45
# 4  2004-05                 72                22                    43

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 229 non-null    object
#  1   diet: (Worldwide)     229 non-null    int64
#  2   gym: (Worldwide)      229 non-null    int64
#  3   finance: (Worldwide)  229 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.3+ KB

# %% [markdown]
# ## Wrangle your data

# %%
df['Month'] = pd.to_datetime(df.Month)
df.rename(columns={'diet: (Worldwide)':'diet','gym: (Worldwide)':'gym','finance: (Worldwide)':'finance'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Month    229 non-null    datetime64[ns]
#  1   diet     229 non-null    int64
#  2   gym      229 non-null    int64
#  3   finance  229 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 7.3 KB

# %%
df
# Out:
#          Month  diet  gym  finance
# 0   2004-01-01   100   28       47
# 1   2004-02-01    73   24       47
# 2   2004-03-01    66   23       45
# 3   2004-04-01    69   21       45
# 4   2004-05-01    72   22       43
# ..         ...   ...  ...      ...
# 224 2022-09-01    29   49       56
# 225 2022-10-01    28   48       53
# 226 2022-11-01    29   51       55
# 227 2022-12-01    26   48       50
# 228 2023-01-01    34   60       55
#
# [229 rows x 4 columns]

# %%
df.set_index('Month',inplace=True)

# %%
df.head()
# Out:
#             diet  gym  finance
# Month
# 2004-01-01   100   28       47
# 2004-02-01    73   24       47
# 2004-03-01    66   23       45
# 2004-04-01    69   21       45
# 2004-05-01    72   22       43

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 229 entries, 2004-01-01 to 2023-01-01
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   diet     229 non-null    int64
#  1   gym      229 non-null    int64
#  2   finance  229 non-null    int64
# dtypes: int64(3)
# memory usage: 7.2 KB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df[['diet']].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# ## Trends and Seasonality in Time Series Data

# %%
df[['diet']].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df[['finance']].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df[['finance']].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df[['gym']].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df[['gym']].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
pd.concat([df[['diet']].rolling(12).mean(),df[['gym']].rolling(12).mean()],axis=1).plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# # Thanks!
